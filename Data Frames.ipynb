# %%
import pandas as pd

# %%
#method1 :specify full path to file

# %%
import pandas as pd

# %%
df11 = pd.read_csv('C:\\Users\\anil\\Desktop\\STUDY AREA\\PYTHON FOR DATA SCIENCE\\DemographicData.csv',sep = ',')

# %%
df11
# Out:
#              Country Name Country Code  Birth rate  Internet users  \
# 0                   Aruba          ABW      10.244            78.9
# 1             Afghanistan          AFG      35.253             5.9
# 2                  Angola          AGO      45.985            19.1
# 3                 Albania          ALB      12.877            57.2
# 4    United Arab Emirates          ARE      11.044            88.0
# ..                    ...          ...         ...             ...
# 190           Yemen, Rep.          YEM      32.947            20.0
# 191          South Africa          ZAF      20.850            46.5
# 192      Congo, Dem. Rep.          COD      42.394             2.2
# 193                Zambia          ZMB      40.471            15.4
# 194              Zimbabwe          ZWE      35.715            18.5
#
#             Income Group
# 0            High income
# 1             Low income
# 2    Upper middle income
# 3    Upper middle income
# 4            High income
# ...

# %%
import os

# %%
print(os.getcwd())
# Out:
# C:\Users\anil\Desktop\STUDY AREA\PYTHON FOR DATA SCIENCE

# %%
os.chdir('C:\\Users\\anil\\Desktop\\STUDY AREA\\PYTHON FOR DATA SCIENCE')

# %%
import pandas as pd
stats2 = pd.read_csv('http://samplecsvs.s3.amazonaws.com/Sacramentorealestatetransactions.csv')
stats2.head()
# Out:
#              street        city    zip state  beds  baths  sq__ft  \
# 0      3526 HIGH ST  SACRAMENTO  95838    CA     2      1     836
# 1       51 OMAHA CT  SACRAMENTO  95823    CA     3      1    1167
# 2    2796 BRANCH ST  SACRAMENTO  95815    CA     2      1     796
# 3  2805 JANETTE WAY  SACRAMENTO  95815    CA     2      1     852
# 4   6001 MCMAHON DR  SACRAMENTO  95824    CA     2      1     797
#
#           type                     sale_date  price   latitude   longitude
# 0  Residential  Wed May 21 00:00:00 EDT 2008  59222  38.631913 -121.434879
# 1  Residential  Wed May 21 00:00:00 EDT 2008  68212  38.478902 -121.431028
# 2  Residential  Wed May 21 00:00:00 EDT 2008  68880  38.618305 -121.443839
# 3  Residential  Wed May 21 00:00:00 EDT 2008  69307  38.616835 -121.439146
# 4  Residential  Wed May 21 00:00:00 EDT 2008  81900  38.519470 -121.435768

# %%
import pandas as pd
csv_file ='http://samplecsvs.s3.amazonaws.com/Sacramentorealestatetransactions.csv' 
f = pd.read_csv(csv_file,sep = ',')
f.head()
# Out:
#              street        city    zip state  beds  baths  sq__ft  \
# 0      3526 HIGH ST  SACRAMENTO  95838    CA     2      1     836
# 1       51 OMAHA CT  SACRAMENTO  95823    CA     3      1    1167
# 2    2796 BRANCH ST  SACRAMENTO  95815    CA     2      1     796
# 3  2805 JANETTE WAY  SACRAMENTO  95815    CA     2      1     852
# 4   6001 MCMAHON DR  SACRAMENTO  95824    CA     2      1     797
#
#           type                     sale_date  price   latitude   longitude
# 0  Residential  Wed May 21 00:00:00 EDT 2008  59222  38.631913 -121.434879
# 1  Residential  Wed May 21 00:00:00 EDT 2008  68212  38.478902 -121.431028
# 2  Residential  Wed May 21 00:00:00 EDT 2008  68880  38.618305 -121.443839
# 3  Residential  Wed May 21 00:00:00 EDT 2008  69307  38.616835 -121.439146
# 4  Residential  Wed May 21 00:00:00 EDT 2008  81900  38.519470 -121.435768

# %%
f.to_csv("newfilename.csv",sep=',')

# %%
import pandas as pd
csv_file ='newfilename.csv' 
f = pd.read_csv(csv_file,sep = ',')
f.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1            street        city    zip state  beds  \
# 0           0             0      3526 HIGH ST  SACRAMENTO  95838    CA     2
# 1           1             1       51 OMAHA CT  SACRAMENTO  95823    CA     3
# 2           2             2    2796 BRANCH ST  SACRAMENTO  95815    CA     2
# 3           3             3  2805 JANETTE WAY  SACRAMENTO  95815    CA     2
# 4           4             4   6001 MCMAHON DR  SACRAMENTO  95824    CA     2
#
#    baths  sq__ft         type                     sale_date  price   latitude  \
# 0      1     836  Residential  Wed May 21 00:00:00 EDT 2008  59222  38.631913
# 1      1    1167  Residential  Wed May 21 00:00:00 EDT 2008  68212  38.478902
# 2      1     796  Residential  Wed May 21 00:00:00 EDT 2008  68880  38.618305
# 3      1     852  Residential  Wed May 21 00:00:00 EDT 2008  69307  38.616835
# 4      1     797  Residential  Wed May 21 00:00:00 EDT 2008  81900  38.519470
#
#     longitude
# 0 -121.434879
# ...

# %%
#--- EXPLORING YOUR DATASET---#

# %%
#1 full dataframe
f
# Out:
#      Unnamed: 0  Unnamed: 0.1               street             city    zip  \
# 0             0             0         3526 HIGH ST       SACRAMENTO  95838
# 1             1             1          51 OMAHA CT       SACRAMENTO  95823
# 2             2             2       2796 BRANCH ST       SACRAMENTO  95815
# 3             3             3     2805 JANETTE WAY       SACRAMENTO  95815
# 4             4             4      6001 MCMAHON DR       SACRAMENTO  95824
# ..          ...           ...                  ...              ...    ...
# 980         980           980   9169 GARLINGTON CT       SACRAMENTO  95829
# 981         981           981      6932 RUSKUT WAY       SACRAMENTO  95823
# 982         982           982    7933 DAFFODIL WAY   CITRUS HEIGHTS  95610
# 983         983           983     8304 RED FOX WAY        ELK GROVE  95758
# 984         984           984  3882 YELLOWSTONE LN  EL DORADO HILLS  95762
#
# ...

# %%
#2 no of rows
len(f) #985 rows imported
# Out:
# 985

# %%
#3  see the columns
f.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 0.1', 'street', 'city', 'zip', 'state', 'beds',
#        'baths', 'sq__ft', 'type', 'sale_date', 'price', 'latitude',
#        'longitude'],
#       dtype='object')

# %%
len(f.columns)
# Out:
# 14

# %%
#6 top rows
f.head(6)
# Out:
#    Unnamed: 0  Unnamed: 0.1              street        city    zip state  \
# 0           0             0        3526 HIGH ST  SACRAMENTO  95838    CA
# 1           1             1         51 OMAHA CT  SACRAMENTO  95823    CA
# 2           2             2      2796 BRANCH ST  SACRAMENTO  95815    CA
# 3           3             3    2805 JANETTE WAY  SACRAMENTO  95815    CA
# 4           4             4     6001 MCMAHON DR  SACRAMENTO  95824    CA
# 5           5             5  5828 PEPPERMILL CT  SACRAMENTO  95841    CA
#
#    beds  baths  sq__ft         type                     sale_date  price  \
# 0     2      1     836  Residential  Wed May 21 00:00:00 EDT 2008  59222
# 1     3      1    1167  Residential  Wed May 21 00:00:00 EDT 2008  68212
# 2     2      1     796  Residential  Wed May 21 00:00:00 EDT 2008  68880
# 3     2      1     852  Residential  Wed May 21 00:00:00 EDT 2008  69307
# 4     2      1     797  Residential  Wed May 21 00:00:00 EDT 2008  81900
# ...

# %%
 #6 bottom rows
f.tail(6)
# Out:
#      Unnamed: 0  Unnamed: 0.1               street             city    zip  \
# 979         979           979     1909 YARNELL WAY        ELK GROVE  95758
# 980         980           980   9169 GARLINGTON CT       SACRAMENTO  95829
# 981         981           981      6932 RUSKUT WAY       SACRAMENTO  95823
# 982         982           982    7933 DAFFODIL WAY   CITRUS HEIGHTS  95610
# 983         983           983     8304 RED FOX WAY        ELK GROVE  95758
# 984         984           984  3882 YELLOWSTONE LN  EL DORADO HILLS  95762
#
#     state  beds  baths  sq__ft         type                     sale_date  \
# 979    CA     3      2    1262  Residential  Thu May 15 00:00:00 EDT 2008
# 980    CA     4      3    2280  Residential  Thu May 15 00:00:00 EDT 2008
# 981    CA     3      2    1477  Residential  Thu May 15 00:00:00 EDT 2008
# 982    CA     3      2    1216  Residential  Thu May 15 00:00:00 EDT 2008
# ...

# %%
#7 information on columns
f.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 985 entries, 0 to 984
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    985 non-null    int64
#  1   Unnamed: 0.1  985 non-null    int64
#  2   street        985 non-null    object
#  3   city          985 non-null    object
#  4   zip           985 non-null    int64
#  5   state         985 non-null    object
#  6   beds          985 non-null    int64
#  7   baths         985 non-null    int64
#  8   sq__ft        985 non-null    int64
#  9   type          985 non-null    object
#  10  sale_date     985 non-null    object
#  11  price         985 non-null    int64
#  12  latitude      985 non-null    float64
#  13  longitude     985 non-null    float64
# dtypes: float64(2), int64(7), object(5)
# memory usage: 107.9+ KB

# %%
#9 get stats on the columns
f.describe() # this is like summary function
# Out:
#        Unnamed: 0  Unnamed: 0.1           zip        beds       baths  \
# count  985.000000    985.000000    985.000000  985.000000  985.000000
# mean   492.000000    492.000000  95750.697462    2.911675    1.776650
# std    284.489309    284.489309     85.176072    1.307932    0.895371
# min      0.000000      0.000000  95603.000000    0.000000    0.000000
# 25%    246.000000    246.000000  95660.000000    2.000000    1.000000
# 50%    492.000000    492.000000  95762.000000    3.000000    2.000000
# 75%    738.000000    738.000000  95828.000000    4.000000    2.000000
# max    984.000000    984.000000  95864.000000    8.000000    5.000000
#
#             sq__ft          price    latitude   longitude
# count   985.000000     985.000000  985.000000  985.000000
# mean   1314.916751  234144.263959   38.607732 -121.355982
# std     853.048243  138365.839085    0.145433    0.138278
# min       0.000000    1551.000000   38.241514 -121.551704
# ...

# %%
f.describe().transpose()
# Out:
#               count           mean            std           min  \
# Unnamed: 0    985.0     492.000000     284.489309      0.000000
# Unnamed: 0.1  985.0     492.000000     284.489309      0.000000
# zip           985.0   95750.697462      85.176072  95603.000000
# beds          985.0       2.911675       1.307932      0.000000
# baths         985.0       1.776650       0.895371      0.000000
# sq__ft        985.0    1314.916751     853.048243      0.000000
# price         985.0  234144.263959  138365.839085   1551.000000
# latitude      985.0      38.607732       0.145433     38.241514
# longitude     985.0    -121.355982       0.138278   -121.551704
#
#                         25%            50%            75%            max
# Unnamed: 0       246.000000     492.000000     738.000000     984.000000
# Unnamed: 0.1     246.000000     492.000000     738.000000     984.000000
# zip            95660.000000   95762.000000   95828.000000   95864.000000
# ...

# %% [markdown]
#  ###### RENAMING COLUMNS OF THE DATAFRAME

# %%
f.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1            street        city    zip state  beds  \
# 0           0             0      3526 HIGH ST  SACRAMENTO  95838    CA     2
# 1           1             1       51 OMAHA CT  SACRAMENTO  95823    CA     3
# 2           2             2    2796 BRANCH ST  SACRAMENTO  95815    CA     2
# 3           3             3  2805 JANETTE WAY  SACRAMENTO  95815    CA     2
# 4           4             4   6001 MCMAHON DR  SACRAMENTO  95824    CA     2
#
#    baths  sq__ft         type                     sale_date  price   latitude  \
# 0      1     836  Residential  Wed May 21 00:00:00 EDT 2008  59222  38.631913
# 1      1    1167  Residential  Wed May 21 00:00:00 EDT 2008  68212  38.478902
# 2      1     796  Residential  Wed May 21 00:00:00 EDT 2008  68880  38.618305
# 3      1     852  Residential  Wed May 21 00:00:00 EDT 2008  69307  38.616835
# 4      1     797  Residential  Wed May 21 00:00:00 EDT 2008  81900  38.519470
#
#     longitude
# 0 -121.434879
# ...

# %%
f.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 0.1', 'street', 'city', 'zip', 'state', 'beds',
#        'baths', 'sq__ft', 'type', 'sale_date', 'price', 'latitude',
#        'longitude'],
#       dtype='object')

# %%
f.coulmns = ['SNO', 'street', 'city', 'zip', 'state', 'beds', 'baths',
       'sq__ft', 'type', 'sale_date', 'price', 'latitude', 'longitude']
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access

# %%
f.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1            street        city    zip state  beds  \
# 0           0             0      3526 HIGH ST  SACRAMENTO  95838    CA     2
# 1           1             1       51 OMAHA CT  SACRAMENTO  95823    CA     3
# 2           2             2    2796 BRANCH ST  SACRAMENTO  95815    CA     2
# 3           3             3  2805 JANETTE WAY  SACRAMENTO  95815    CA     2
# 4           4             4   6001 MCMAHON DR  SACRAMENTO  95824    CA     2
#
#    baths  sq__ft         type                     sale_date  price   latitude  \
# 0      1     836  Residential  Wed May 21 00:00:00 EDT 2008  59222  38.631913
# 1      1    1167  Residential  Wed May 21 00:00:00 EDT 2008  68212  38.478902
# 2      1     796  Residential  Wed May 21 00:00:00 EDT 2008  68880  38.618305
# 3      1     852  Residential  Wed May 21 00:00:00 EDT 2008  69307  38.616835
# 4      1     797  Residential  Wed May 21 00:00:00 EDT 2008  81900  38.519470
#
#     longitude
# 0 -121.434879
# ...

# %%
##SUBSETTING DATAFRAMES IN PANDAS

# %%
f[2:9]
# Out:
#    Unnamed: 0  Unnamed: 0.1                           street            city  \
# 2           2             2                   2796 BRANCH ST      SACRAMENTO
# 3           3             3                 2805 JANETTE WAY      SACRAMENTO
# 4           4             4                  6001 MCMAHON DR      SACRAMENTO
# 5           5             5               5828 PEPPERMILL CT      SACRAMENTO
# 6           6             6              6048 OGDEN NASH WAY      SACRAMENTO
# 7           7             7                    2561 19TH AVE      SACRAMENTO
# 8           8             8  11150 TRINITY RIVER DR Unit 114  RANCHO CORDOVA
#
#      zip state  beds  baths  sq__ft         type  \
# 2  95815    CA     2      1     796  Residential
# 3  95815    CA     2      1     852  Residential
# 4  95824    CA     2      1     797  Residential
# 5  95841    CA     3      1    1122        Condo
# 6  95842    CA     3      2    1104  Residential
# 7  95820    CA     3      1    1177  Residential
# ...

# %%
#reversing the dataframe
f[::-1]
# Out:
#      Unnamed: 0  Unnamed: 0.1               street             city    zip  \
# 984         984           984  3882 YELLOWSTONE LN  EL DORADO HILLS  95762
# 983         983           983     8304 RED FOX WAY        ELK GROVE  95758
# 982         982           982    7933 DAFFODIL WAY   CITRUS HEIGHTS  95610
# 981         981           981      6932 RUSKUT WAY       SACRAMENTO  95823
# 980         980           980   9169 GARLINGTON CT       SACRAMENTO  95829
# ..          ...           ...                  ...              ...    ...
# 4             4             4      6001 MCMAHON DR       SACRAMENTO  95824
# 3             3             3     2805 JANETTE WAY       SACRAMENTO  95815
# 2             2             2       2796 BRANCH ST       SACRAMENTO  95815
# 1             1             1          51 OMAHA CT       SACRAMENTO  95823
# 0             0             0         3526 HIGH ST       SACRAMENTO  95838
#
# ...

# %%
f[::20]
# Out:
#      Unnamed: 0  Unnamed: 0.1                        street             city  \
# 0             0             0                  3526 HIGH ST       SACRAMENTO
# 20           20            20            6118 STONEHAND AVE   CITRUS HEIGHTS
# 40           40            40  4800 WESTLAKE PKWY Unit 2109       SACRAMENTO
# 60           60            60            4844 CLYDEBANK WAY         ANTELOPE
# 80           80            80                   5037 J PKWY       SACRAMENTO
# 100         100           100         12209 CONSERVANCY WAY   RANCHO CORDOVA
# 120         120           120                4359 CREGAN CT   RANCHO CORDOVA
# 140         140           140                     1300 F ST       SACRAMENTO
# 160         160           160   9512 EMERALD PARK DR Unit 3        ELK GROVE
# 180         180           180              211 MCDANIEL CIR       SACRAMENTO
# 200         200           200            4660 CEDARWOOD WAY       SACRAMENTO
# ...

# %%
f.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1            street        city    zip state  beds  \
# 0           0             0      3526 HIGH ST  SACRAMENTO  95838    CA     2
# 1           1             1       51 OMAHA CT  SACRAMENTO  95823    CA     3
# 2           2             2    2796 BRANCH ST  SACRAMENTO  95815    CA     2
# 3           3             3  2805 JANETTE WAY  SACRAMENTO  95815    CA     2
# 4           4             4   6001 MCMAHON DR  SACRAMENTO  95824    CA     2
#
#    baths  sq__ft         type                     sale_date  price   latitude  \
# 0      1     836  Residential  Wed May 21 00:00:00 EDT 2008  59222  38.631913
# 1      1    1167  Residential  Wed May 21 00:00:00 EDT 2008  68212  38.478902
# 2      1     796  Residential  Wed May 21 00:00:00 EDT 2008  68880  38.618305
# 3      1     852  Residential  Wed May 21 00:00:00 EDT 2008  69307  38.616835
# 4      1     797  Residential  Wed May 21 00:00:00 EDT 2008  81900  38.519470
#
#     longitude
# 0 -121.434879
# ...

# %%
f['street']
# Out:
# 0             3526 HIGH ST
# 1              51 OMAHA CT
# 2           2796 BRANCH ST
# 3         2805 JANETTE WAY
# 4          6001 MCMAHON DR
#               ...
# 980     9169 GARLINGTON CT
# 981        6932 RUSKUT WAY
# 982      7933 DAFFODIL WAY
# 983       8304 RED FOX WAY
# 984    3882 YELLOWSTONE LN
# Name: street, Length: 985, dtype: object

# %%
f[['street','state']].head(6)
# Out:
#                street state
# 0        3526 HIGH ST    CA
# 1         51 OMAHA CT    CA
# 2      2796 BRANCH ST    CA
# 3    2805 JANETTE WAY    CA
# 4     6001 MCMAHON DR    CA
# 5  5828 PEPPERMILL CT    CA

# %%
['street','state']
# Out:
# ['street', 'state']

# %%
#Quick access - requires the name to be one word

# %%
f.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1            street        city    zip state  beds  \
# 0           0             0      3526 HIGH ST  SACRAMENTO  95838    CA     2
# 1           1             1       51 OMAHA CT  SACRAMENTO  95823    CA     3
# 2           2             2    2796 BRANCH ST  SACRAMENTO  95815    CA     2
# 3           3             3  2805 JANETTE WAY  SACRAMENTO  95815    CA     2
# 4           4             4   6001 MCMAHON DR  SACRAMENTO  95824    CA     2
#
#    baths  sq__ft         type                     sale_date  price   latitude  \
# 0      1     836  Residential  Wed May 21 00:00:00 EDT 2008  59222  38.631913
# 1      1    1167  Residential  Wed May 21 00:00:00 EDT 2008  68212  38.478902
# 2      1     796  Residential  Wed May 21 00:00:00 EDT 2008  68880  38.618305
# 3      1     852  Residential  Wed May 21 00:00:00 EDT 2008  69307  38.616835
# 4      1     797  Residential  Wed May 21 00:00:00 EDT 2008  81900  38.519470
#
#     longitude
# 0 -121.434879
# ...

# %%
f['street']
# Out:
# 0             3526 HIGH ST
# 1              51 OMAHA CT
# 2           2796 BRANCH ST
# 3         2805 JANETTE WAY
# 4          6001 MCMAHON DR
#               ...
# 980     9169 GARLINGTON CT
# 981        6932 RUSKUT WAY
# 982      7933 DAFFODIL WAY
# 983       8304 RED FOX WAY
# 984    3882 YELLOWSTONE LN
# Name: street, Length: 985, dtype: object

# %%
f.city.head(59)
# Out:
# 0          SACRAMENTO
# 1          SACRAMENTO
# 2          SACRAMENTO
# 3          SACRAMENTO
# 4          SACRAMENTO
# 5          SACRAMENTO
# 6          SACRAMENTO
# 7          SACRAMENTO
# 8      RANCHO CORDOVA
# 9           RIO LINDA
# 10         SACRAMENTO
# 11         SACRAMENTO
# 12         SACRAMENTO
# 13         SACRAMENTO
# 14         SACRAMENTO
# 15         SACRAMENTO
# 16          RIO LINDA
# 17     CITRUS HEIGHTS
# 18         SACRAMENTO
# 19          RIO LINDA
# 20     CITRUS HEIGHTS
# 21         SACRAMENTO
# 22    NORTH HIGHLANDS
# 23         SACRAMENTO
# 24    NORTH HIGHLANDS
# 25           ANTELOPE
# 26         SACRAMENTO
# 27         SACRAMENTO
# 28         SACRAMENTO
# 29         SACRAMENTO
# 30          ELK GROVE
# 31    NORTH HIGHLANDS
# 32         SACRAMENTO
# 33            ELVERTA
# 34          ELK GROVE
# 35         SACRAMENTO
# 36    NORTH HIGHLANDS
# 37         SACRAMENTO
# 38         SACRAMENTO
# 39         SACRAMENTO
# 40         SACRAMENTO
# ...

# %%
## COMBINING THE TWO
f[0:6][['street','city']]
# Out:
#                street        city
# 0        3526 HIGH ST  SACRAMENTO
# 1         51 OMAHA CT  SACRAMENTO
# 2      2796 BRANCH ST  SACRAMENTO
# 3    2805 JANETTE WAY  SACRAMENTO
# 4     6001 MCMAHON DR  SACRAMENTO
# 5  5828 PEPPERMILL CT  SACRAMENTO

# %%
f[['street','city']][0:6]
# Out:
#                street        city
# 0        3526 HIGH ST  SACRAMENTO
# 1         51 OMAHA CT  SACRAMENTO
# 2      2796 BRANCH ST  SACRAMENTO
# 3    2805 JANETTE WAY  SACRAMENTO
# 4     6001 MCMAHON DR  SACRAMENTO
# 5  5828 PEPPERMILL CT  SACRAMENTO

# %% [markdown]
# ## BASIC OPERATIONS WITH DATAFRAME

# %%
#ALREADY SPOKE ABOUT SUBSETTING

# %%
f[['street','city','state']][1:6]
# Out:
#                street        city state
# 1         51 OMAHA CT  SACRAMENTO    CA
# 2      2796 BRANCH ST  SACRAMENTO    CA
# 3    2805 JANETTE WAY  SACRAMENTO    CA
# 4     6001 MCMAHON DR  SACRAMENTO    CA
# 5  5828 PEPPERMILL CT  SACRAMENTO    CA

# %%
f[1:5]
# Out:
#    Unnamed: 0  Unnamed: 0.1            street        city    zip state  beds  \
# 1           1             1       51 OMAHA CT  SACRAMENTO  95823    CA     3
# 2           2             2    2796 BRANCH ST  SACRAMENTO  95815    CA     2
# 3           3             3  2805 JANETTE WAY  SACRAMENTO  95815    CA     2
# 4           4             4   6001 MCMAHON DR  SACRAMENTO  95824    CA     2
#
#    baths  sq__ft         type                     sale_date  price   latitude  \
# 1      1    1167  Residential  Wed May 21 00:00:00 EDT 2008  68212  38.478902
# 2      1     796  Residential  Wed May 21 00:00:00 EDT 2008  68880  38.618305
# 3      1     852  Residential  Wed May 21 00:00:00 EDT 2008  69307  38.616835
# 4      1     797  Residential  Wed May 21 00:00:00 EDT 2008  81900  38.519470
#
#     longitude
# 1 -121.431028
# 2 -121.443839
# 3 -121.439146
# 4 -121.435768

# %%
result = f.price * f.price

# %%
result.head()
# Out:
# 0    3507245284
# 1    4652876944
# 2    4744454400
# 3    4803460249
# 4    6707610000
# Name: price, dtype: int64

# %%
f.price.tail()
# Out:
# 980    232425
# 981    234000
# 982    235000
# 983    235301
# 984    235738
# Name: price, dtype: int64

# %%
##add column

# %%
f['MyCalc'] = f.price *f.price

# %%
f[1:5]
# Out:
#    Unnamed: 0  Unnamed: 0.1            street        city    zip state  beds  \
# 1           1             1       51 OMAHA CT  SACRAMENTO  95823    CA     3
# 2           2             2    2796 BRANCH ST  SACRAMENTO  95815    CA     2
# 3           3             3  2805 JANETTE WAY  SACRAMENTO  95815    CA     2
# 4           4             4   6001 MCMAHON DR  SACRAMENTO  95824    CA     2
#
#    baths  sq__ft         type                     sale_date  price   latitude  \
# 1      1    1167  Residential  Wed May 21 00:00:00 EDT 2008  68212  38.478902
# 2      1     796  Residential  Wed May 21 00:00:00 EDT 2008  68880  38.618305
# 3      1     852  Residential  Wed May 21 00:00:00 EDT 2008  69307  38.616835
# 4      1     797  Residential  Wed May 21 00:00:00 EDT 2008  81900  38.519470
#
#     longitude      MyCalc
# 1 -121.431028  4652876944
# 2 -121.443839  4744454400
# 3 -121.439146  4803460249
# 4 -121.435768  6707610000

# %%
#comparisions         
f['xyz'] = [1,2,3,4,]  #ERROR NO RECYCLING OPTION
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-58-a3c3ec6eaf9e> in <module>
#       1 #comparisions
# ----> 2 f['xyz'] = [1,2,3,4,]  #ERROR NO RECYCLING OPTION
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in __setitem__(self, key, value)
#    2936         else:
#    2937             # set column
# -> 2938             self._set_item(key, value)
#    2939
#    2940     def _setitem_slice(self, key, value):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in _set_item(self, key, value)
#    2998
#    2999         self._ensure_valid_index(value)
# -> 3000         value = self._sanitize_column(key, value)
#    3001         NDFrame._set_item(self, key, value)
#    3002
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in _sanitize_column(self, key, value, broadcast)
#    3634
# ...

# %%
#REMOVING A COLUM
f.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1            street        city    zip state  beds  \
# 0           0             0      3526 HIGH ST  SACRAMENTO  95838    CA     2
# 1           1             1       51 OMAHA CT  SACRAMENTO  95823    CA     3
# 2           2             2    2796 BRANCH ST  SACRAMENTO  95815    CA     2
# 3           3             3  2805 JANETTE WAY  SACRAMENTO  95815    CA     2
# 4           4             4   6001 MCMAHON DR  SACRAMENTO  95824    CA     2
#
#    baths  sq__ft         type                     sale_date  price   latitude  \
# 0      1     836  Residential  Wed May 21 00:00:00 EDT 2008  59222  38.631913
# 1      1    1167  Residential  Wed May 21 00:00:00 EDT 2008  68212  38.478902
# 2      1     796  Residential  Wed May 21 00:00:00 EDT 2008  68880  38.618305
# 3      1     852  Residential  Wed May 21 00:00:00 EDT 2008  69307  38.616835
# 4      1     797  Residential  Wed May 21 00:00:00 EDT 2008  81900  38.519470
#
#     longitude      MyCalc
# ...

# %%
f.drop('MyCalc',1)
# Out:
#      Unnamed: 0  Unnamed: 0.1               street             city    zip  \
# 0             0             0         3526 HIGH ST       SACRAMENTO  95838
# 1             1             1          51 OMAHA CT       SACRAMENTO  95823
# 2             2             2       2796 BRANCH ST       SACRAMENTO  95815
# 3             3             3     2805 JANETTE WAY       SACRAMENTO  95815
# 4             4             4      6001 MCMAHON DR       SACRAMENTO  95824
# ..          ...           ...                  ...              ...    ...
# 980         980           980   9169 GARLINGTON CT       SACRAMENTO  95829
# 981         981           981      6932 RUSKUT WAY       SACRAMENTO  95823
# 982         982           982    7933 DAFFODIL WAY   CITRUS HEIGHTS  95610
# 983         983           983     8304 RED FOX WAY        ELK GROVE  95758
# 984         984           984  3882 YELLOWSTONE LN  EL DORADO HILLS  95762
#
# ...

# %%
f.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1            street        city    zip state  beds  \
# 0           0             0      3526 HIGH ST  SACRAMENTO  95838    CA     2
# 1           1             1       51 OMAHA CT  SACRAMENTO  95823    CA     3
# 2           2             2    2796 BRANCH ST  SACRAMENTO  95815    CA     2
# 3           3             3  2805 JANETTE WAY  SACRAMENTO  95815    CA     2
# 4           4             4   6001 MCMAHON DR  SACRAMENTO  95824    CA     2
#
#    baths  sq__ft         type                     sale_date  price   latitude  \
# 0      1     836  Residential  Wed May 21 00:00:00 EDT 2008  59222  38.631913
# 1      1    1167  Residential  Wed May 21 00:00:00 EDT 2008  68212  38.478902
# 2      1     796  Residential  Wed May 21 00:00:00 EDT 2008  68880  38.618305
# 3      1     852  Residential  Wed May 21 00:00:00 EDT 2008  69307  38.616835
# 4      1     797  Residential  Wed May 21 00:00:00 EDT 2008  81900  38.519470
#
#     longitude      MyCalc
# ...

# %%
f = f.drop('MyCalc',1)

# %%
f
# Out:
#      Unnamed: 0  Unnamed: 0.1               street             city    zip  \
# 0             0             0         3526 HIGH ST       SACRAMENTO  95838
# 1             1             1          51 OMAHA CT       SACRAMENTO  95823
# 2             2             2       2796 BRANCH ST       SACRAMENTO  95815
# 3             3             3     2805 JANETTE WAY       SACRAMENTO  95815
# 4             4             4      6001 MCMAHON DR       SACRAMENTO  95824
# ..          ...           ...                  ...              ...    ...
# 980         980           980   9169 GARLINGTON CT       SACRAMENTO  95829
# 981         981           981      6932 RUSKUT WAY       SACRAMENTO  95823
# 982         982           982    7933 DAFFODIL WAY   CITRUS HEIGHTS  95610
# 983         983           983     8304 RED FOX WAY        ELK GROVE  95758
# 984         984           984  3882 YELLOWSTONE LN  EL DORADO HILLS  95762
#
# ...

# %%
f
# Out:
#      Unnamed: 0  Unnamed: 0.1               street             city    zip  \
# 0             0             0         3526 HIGH ST       SACRAMENTO  95838
# 1             1             1          51 OMAHA CT       SACRAMENTO  95823
# 2             2             2       2796 BRANCH ST       SACRAMENTO  95815
# 3             3             3     2805 JANETTE WAY       SACRAMENTO  95815
# 4             4             4      6001 MCMAHON DR       SACRAMENTO  95824
# ..          ...           ...                  ...              ...    ...
# 980         980           980   9169 GARLINGTON CT       SACRAMENTO  95829
# 981         981           981      6932 RUSKUT WAY       SACRAMENTO  95823
# 982         982           982    7933 DAFFODIL WAY   CITRUS HEIGHTS  95610
# 983         983           983     8304 RED FOX WAY        ELK GROVE  95758
# 984         984           984  3882 YELLOWSTONE LN  EL DORADO HILLS  95762
#
# ...

# %% [markdown]
# #########FILTERING A DATA FRAME

# %%
#FILTERING IS ABOUT ROWS

# %%
f.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1            street        city    zip state  beds  \
# 0           0             0      3526 HIGH ST  SACRAMENTO  95838    CA     2
# 1           1             1       51 OMAHA CT  SACRAMENTO  95823    CA     3
# 2           2             2    2796 BRANCH ST  SACRAMENTO  95815    CA     2
# 3           3             3  2805 JANETTE WAY  SACRAMENTO  95815    CA     2
# 4           4             4   6001 MCMAHON DR  SACRAMENTO  95824    CA     2
#
#    baths  sq__ft         type                     sale_date  price   latitude  \
# 0      1     836  Residential  Wed May 21 00:00:00 EDT 2008  59222  38.631913
# 1      1    1167  Residential  Wed May 21 00:00:00 EDT 2008  68212  38.478902
# 2      1     796  Residential  Wed May 21 00:00:00 EDT 2008  68880  38.618305
# 3      1     852  Residential  Wed May 21 00:00:00 EDT 2008  69307  38.616835
# 4      1     797  Residential  Wed May 21 00:00:00 EDT 2008  81900  38.519470
#
#     longitude
# 0 -121.434879
# ...

# %%
f.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 0.1', 'street', 'city', 'zip', 'state', 'beds',
#        'baths', 'sq__ft', 'type', 'sale_date', 'price', 'latitude',
#        'longitude'],
#       dtype='object')

# %%
f.beds >2
# Out:
# 0      False
# 1       True
# 2      False
# 3      False
# 4      False
#        ...
# 980     True
# 981     True
# 982     True
# 983     True
# 984     True
# Name: beds, Length: 985, dtype: bool

# %%
Filter = f.beds>2

# %%
Filter
# Out:
# 0      False
# 1       True
# 2      False
# 3      False
# 4      False
#        ...
# 980     True
# 981     True
# 982     True
# 983     True
# 984     True
# Name: beds, Length: 985, dtype: bool

# %%
f[30:41]
# Out:
#     Unnamed: 0  Unnamed: 0.1                        street             city  \
# 30          30            30  5201 LAGUNA OAKS DR Unit 140        ELK GROVE
# 31          31            31                6768 MEDORA DR  NORTH HIGHLANDS
# 32          32            32              3100 EXPLORER DR       SACRAMENTO
# 33          33            33             7944 DOMINION WAY          ELVERTA
# 34          34            34  5201 LAGUNA OAKS DR Unit 162        ELK GROVE
# 35          35            35          3920 SHINING STAR DR       SACRAMENTO
# 36          36            36               5031 CORVAIR ST  NORTH HIGHLANDS
# 37          37            37                7661 NIXOS WAY       SACRAMENTO
# 38          38            38               7044 CARTHY WAY       SACRAMENTO
# 39          39            39              2442 LARKSPUR LN       SACRAMENTO
# 40          40            40  4800 WESTLAKE PKWY Unit 2109       SACRAMENTO
#
#       zip state  beds  baths  sq__ft         type  \
# ...

# %%
f[Filter]
# Out:
#      Unnamed: 0  Unnamed: 0.1               street             city    zip  \
# 1             1             1          51 OMAHA CT       SACRAMENTO  95823
# 5             5             5   5828 PEPPERMILL CT       SACRAMENTO  95841
# 6             6             6  6048 OGDEN NASH WAY       SACRAMENTO  95842
# 7             7             7        2561 19TH AVE       SACRAMENTO  95820
# 9             9             9         7325 10TH ST        RIO LINDA  95673
# ..          ...           ...                  ...              ...    ...
# 980         980           980   9169 GARLINGTON CT       SACRAMENTO  95829
# 981         981           981      6932 RUSKUT WAY       SACRAMENTO  95823
# 982         982           982    7933 DAFFODIL WAY   CITRUS HEIGHTS  95610
# 983         983           983     8304 RED FOX WAY        ELK GROVE  95758
# 984         984           984  3882 YELLOWSTONE LN  EL DORADO HILLS  95762
#
# ...

# %%
# lets use this filters in practice
Filter2 = f.price > 70000

# %%
Filter2
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4       True
#        ...
# 980     True
# 981     True
# 982     True
# 983     True
# 984     True
# Name: price, Length: 985, dtype: bool

# %%
f
# Out:
#      Unnamed: 0  Unnamed: 0.1               street             city    zip  \
# 0             0             0         3526 HIGH ST       SACRAMENTO  95838
# 1             1             1          51 OMAHA CT       SACRAMENTO  95823
# 2             2             2       2796 BRANCH ST       SACRAMENTO  95815
# 3             3             3     2805 JANETTE WAY       SACRAMENTO  95815
# 4             4             4      6001 MCMAHON DR       SACRAMENTO  95824
# ..          ...           ...                  ...              ...    ...
# 980         980           980   9169 GARLINGTON CT       SACRAMENTO  95829
# 981         981           981      6932 RUSKUT WAY       SACRAMENTO  95823
# 982         982           982    7933 DAFFODIL WAY   CITRUS HEIGHTS  95610
# 983         983           983     8304 RED FOX WAY        ELK GROVE  95758
# 984         984           984  3882 YELLOWSTONE LN  EL DORADO HILLS  95762
#
# ...

# %%
f[Filter2] #error
# Out:
#      Unnamed: 0  Unnamed: 0.1                           street  \
# 4             4             4                  6001 MCMAHON DR
# 5             5             5               5828 PEPPERMILL CT
# 6             6             6              6048 OGDEN NASH WAY
# 7             7             7                    2561 19TH AVE
# 8             8             8  11150 TRINITY RIVER DR Unit 114
# ..          ...           ...                              ...
# 980         980           980               9169 GARLINGTON CT
# 981         981           981                  6932 RUSKUT WAY
# 982         982           982                7933 DAFFODIL WAY
# 983         983           983                 8304 RED FOX WAY
# 984         984           984              3882 YELLOWSTONE LN
#
#                 city    zip state  beds  baths  sq__ft         type  \
# 4         SACRAMENTO  95824    CA     2      1     797  Residential
# 5         SACRAMENTO  95841    CA     3      1    1122        Condo
# ...

# %%
f.beds>2 and f.baths>1
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-80-bc2b89f90c73> in <module>
# ----> 1 f.beds>2 and f.baths>1
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in __nonzero__(self)
#    1477     def __nonzero__(self):
#    1478         raise ValueError(
# -> 1479             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1480             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#    1481         )
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
f[Filter & Filter2]
# Out:
#      Unnamed: 0  Unnamed: 0.1               street             city    zip  \
# 5             5             5   5828 PEPPERMILL CT       SACRAMENTO  95841
# 6             6             6  6048 OGDEN NASH WAY       SACRAMENTO  95842
# 7             7             7        2561 19TH AVE       SACRAMENTO  95820
# 9             9             9         7325 10TH ST        RIO LINDA  95673
# 10           10            10     645 MORRISON AVE       SACRAMENTO  95838
# ..          ...           ...                  ...              ...    ...
# 980         980           980   9169 GARLINGTON CT       SACRAMENTO  95829
# 981         981           981      6932 RUSKUT WAY       SACRAMENTO  95823
# 982         982           982    7933 DAFFODIL WAY   CITRUS HEIGHTS  95610
# 983         983           983     8304 RED FOX WAY        ELK GROVE  95758
# 984         984           984  3882 YELLOWSTONE LN  EL DORADO HILLS  95762
#
# ...

# %%
f[(f.beds  >1) & (f.price >70000)]
# Out:
#      Unnamed: 0  Unnamed: 0.1                           street  \
# 4             4             4                  6001 MCMAHON DR
# 5             5             5               5828 PEPPERMILL CT
# 6             6             6              6048 OGDEN NASH WAY
# 7             7             7                    2561 19TH AVE
# 8             8             8  11150 TRINITY RIVER DR Unit 114
# ..          ...           ...                              ...
# 980         980           980               9169 GARLINGTON CT
# 981         981           981                  6932 RUSKUT WAY
# 982         982           982                7933 DAFFODIL WAY
# 983         983           983                 8304 RED FOX WAY
# 984         984           984              3882 YELLOWSTONE LN
#
#                 city    zip state  beds  baths  sq__ft         type  \
# 4         SACRAMENTO  95824    CA     2      1     797  Residential
# 5         SACRAMENTO  95841    CA     3      1    1122        Condo
# ...

# %%
##another one
f
# Out:
#      Unnamed: 0  Unnamed: 0.1               street             city    zip  \
# 0             0             0         3526 HIGH ST       SACRAMENTO  95838
# 1             1             1          51 OMAHA CT       SACRAMENTO  95823
# 2             2             2       2796 BRANCH ST       SACRAMENTO  95815
# 3             3             3     2805 JANETTE WAY       SACRAMENTO  95815
# 4             4             4      6001 MCMAHON DR       SACRAMENTO  95824
# ..          ...           ...                  ...              ...    ...
# 980         980           980   9169 GARLINGTON CT       SACRAMENTO  95829
# 981         981           981      6932 RUSKUT WAY       SACRAMENTO  95823
# 982         982           982    7933 DAFFODIL WAY   CITRUS HEIGHTS  95610
# 983         983           983     8304 RED FOX WAY        ELK GROVE  95758
# 984         984           984  3882 YELLOWSTONE LN  EL DORADO HILLS  95762
#
# ...

# %%
f[f.beds == 2]
# Out:
#      Unnamed: 0  Unnamed: 0.1                           street  \
# 0             0             0                     3526 HIGH ST
# 2             2             2                   2796 BRANCH ST
# 3             3             3                 2805 JANETTE WAY
# 4             4             4                  6001 MCMAHON DR
# 8             8             8  11150 TRINITY RIVER DR Unit 114
# ..          ...           ...                              ...
# 926         926           926                 7687 HOWERTON DR
# 928         928           928                   7045 PEEVEY CT
# 951         951           951                     2221 2ND AVE
# 953         953           953            5209 LAGUNA CREST WAY
# 954         954           954                   416 LEITCH AVE
#
#                city    zip state  beds  baths  sq__ft         type  \
# 0        SACRAMENTO  95838    CA     2      1     836  Residential
# 2        SACRAMENTO  95815    CA     2      1     796  Residential
# ...

# %%
# how to get the unique categories
f.beds.unique()
# Out:
# array([2, 3, 1, 4, 0, 5, 8, 6], dtype=int64)

# %%
##Quick excercise:
#find out everything about city of 'CITRUS HEIGHTS'

# %%
f[f.city == 'CITRUS HEIGHTS']
# Out:
#      Unnamed: 0  Unnamed: 0.1                   street            city    zip  \
# 17           17            17  6236 LONGFORD DR Unit 1  CITRUS HEIGHTS  95621
# 20           20            20       6118 STONEHAND AVE  CITRUS HEIGHTS  95621
# 82           82            82           6613 NAVION DR  CITRUS HEIGHTS  95621
# 92           92            92       5448 MAIDSTONE WAY  CITRUS HEIGHTS  95621
# 158         158           158  6272 LONGFORD DR Unit 1  CITRUS HEIGHTS  95621
# 202         202           202        6716 TAREYTON WAY  CITRUS HEIGHTS  95621
# 206         206           206    7140 BLUE SPRINGS WAY  CITRUS HEIGHTS  95621
# 220         220           220      7031 CANEVALLEY CIR  CITRUS HEIGHTS  95621
# 232         232           232        5805 HIMALAYA WAY  CITRUS HEIGHTS  95621
# 233         233           233      7944 SYLVAN OAK WAY  CITRUS HEIGHTS  95610
# 258         258           258          6344 BONHAM CIR  CITRUS HEIGHTS  95610
# ...

# %%
f.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 0.1', 'street', 'city', 'zip', 'state', 'beds',
#        'baths', 'sq__ft', 'type', 'sale_date', 'price', 'latitude',
#        'longitude'],
#       dtype='object')

# %%
f.city
# Out:
# 0           SACRAMENTO
# 1           SACRAMENTO
# 2           SACRAMENTO
# 3           SACRAMENTO
# 4           SACRAMENTO
#             ...
# 980         SACRAMENTO
# 981         SACRAMENTO
# 982     CITRUS HEIGHTS
# 983          ELK GROVE
# 984    EL DORADO HILLS
# Name: city, Length: 985, dtype: object

# %%
###  ACCESSING INDIVIDUAL ELEMENTS

# %%
f[2,2] #error why ???
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: (2, 2)
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-99-7a2b33a7675e> in <module>
# ----> 1 f[2,2] #error why ???
#
# ...

# %%
## .at  #for labels.  important even integers are treated as labels
#.iat  #for integer location.

# %%
f.iat[3,4]
# Out:
# 95815

# %%
f.iat[5,2]
# Out:
# '5828 PEPPERMILL CT'

# %%
f.iat[0,3]
# Out:
# 'SACRAMENTO'

# %%
f.at[2,'price']
# Out:
# 68880

# %%
# why we need .at:

# %%
sub10 = f[::10]

# %%
sub10
# Out:
#      Unnamed: 0  Unnamed: 0.1                        street            city  \
# 0             0             0                  3526 HIGH ST      SACRAMENTO
# 10           10            10              645 MORRISON AVE      SACRAMENTO
# 20           20            20            6118 STONEHAND AVE  CITRUS HEIGHTS
# 30           30            30  5201 LAGUNA OAKS DR Unit 140       ELK GROVE
# 40           40            40  4800 WESTLAKE PKWY Unit 2109      SACRAMENTO
# ..          ...           ...                           ...             ...
# 940         940           940         6601 WOODMORE OAKS DR      ORANGEVALE
# 950         950           950         6600 SILVERTHORNE CIR      SACRAMENTO
# 960         960           960             7958 ROSEVIEW WAY      SACRAMENTO
# 970         970           970                 3557 SODA WAY      SACRAMENTO
# 980         980           980            9169 GARLINGTON CT      SACRAMENTO
#
#        zip state  beds  baths  sq__ft         type  \
# ...

# %%
sub10.iat[10,4]
# Out:
# 95742

# %%
sub10.at[10,'price']
# Out:
# 100309

# %%
f
# Out:
#      Unnamed: 0  Unnamed: 0.1               street             city    zip  \
# 0             0             0         3526 HIGH ST       SACRAMENTO  95838
# 1             1             1          51 OMAHA CT       SACRAMENTO  95823
# 2             2             2       2796 BRANCH ST       SACRAMENTO  95815
# 3             3             3     2805 JANETTE WAY       SACRAMENTO  95815
# 4             4             4      6001 MCMAHON DR       SACRAMENTO  95824
# ..          ...           ...                  ...              ...    ...
# 980         980           980   9169 GARLINGTON CT       SACRAMENTO  95829
# 981         981           981      6932 RUSKUT WAY       SACRAMENTO  95823
# 982         982           982    7933 DAFFODIL WAY   CITRUS HEIGHTS  95610
# 983         983           983     8304 RED FOX WAY        ELK GROVE  95758
# 984         984           984  3882 YELLOWSTONE LN  EL DORADO HILLS  95762
#
# ...
